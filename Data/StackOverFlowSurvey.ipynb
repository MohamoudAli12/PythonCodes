# %% [markdown]
# # Stack Overflow Survey Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
df_schema = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5                                         Employed, full-time
# ...                                                       ...
# 73264                                     Employed, full-time
# 73265                                     Employed, full-time
# 73266                                     Employed, full-time
# 73267                                     Employed, full-time
# 73268       Independent contractor, freelancer, or self-em...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 2                                   Fully remote
# 3           Hybrid (some remote, some in-person)
# 4                                   Fully remote
# 5           Hybrid (some remote, some in-person)
# ...                                          ...
# 73264                               Fully remote
# 73265                             Full in-person
# 73266       Hybrid (some remote, some in-person)
# 73267       Hybrid (some remote, some in-person)
# 73268                               Fully remote
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2                    Hobby;Contribute to open-source projects
# 3                                                       Hobby
# 4                                I don’t code outside of work
# 5                                                       Hobby
# ...                                                       ...
# 73264                                 Freelance/contract work
# 73265                                                   Hobby
# 73266                           Hobby;School or academic work
# 73267                                                   Hobby
# 73268       Hobby;Contribute to open-source projects;Boots...
#
#                                                     EdLevel  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 73264          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73265       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73266          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73268          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Books / Physical media;Friend or family member...
# 4           Books / Physical media;School (i.e., Universit...
# 5           Other online resources (e.g., videos, blogs, f...
# ...                                                       ...
# 73264       Books / Physical media;Other online resources ...
# 73265       Other online resources (e.g., videos, blogs, f...
# 73266       Books / Physical media;Other online resources ...
# 73267              Books / Physical media;On the job training
# 73268       Books / Physical media;Friend or family member...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Technical documentation;Blogs;Programming Game...
# 4                                                         NaN
# 5           Technical documentation;Blogs;Stack Overflow;O...
# ...                                                       ...
# 73264       Technical documentation;Blogs;Written Tutorial...
# 73265       Technical documentation;Blogs;Written Tutorial...
# 73266       Technical documentation;Programming Games;Stac...
# 73267                                                     NaN
# 73268       Technical documentation;Blogs;Programming Game...
#
#                         LearnCodeCoursesCert YearsCode YearsCodePro  ...  \
# ResponseId                                                           ...
# 1                                        NaN       NaN          NaN  ...
# 2                                        NaN       NaN          NaN  ...
# 3                                        NaN        14            5  ...
# 4                                        NaN        20           17  ...
# 5                                        NaN         8            3  ...
# ...                                      ...       ...          ...  ...
# 73264                                  Udemy         8            5  ...
# 73265                 Coursera;Udemy;Udacity         6            5  ...
# 73266       Udemy;Codecademy;Pluralsight;edX        42           33  ...
# 73267                                    NaN        50           31  ...
# 73268                      Udemy;Pluralsight        16            5  ...
#
#                   TimeSearching               TimeAnswering  Onboarding  \
# ResponseId
# 1                           NaN                         NaN         NaN
# 2                           NaN                         NaN         NaN
# 3                           NaN                         NaN         NaN
# 4                           NaN                         NaN         NaN
# 5                           NaN                         NaN         NaN
# ...                         ...                         ...         ...
# 73264       30-60 minutes a day  Less than 15 minutes a day  Just right
# 73265       15-30 minutes a day        60-120 minutes a day   Very long
# 73266       30-60 minutes a day        60-120 minutes a day  Just right
# 73267                       NaN                         NaN         NaN
# 73268                       NaN                         NaN         NaN
#
#                                              ProfessionalTech TrueFalse_1  \
# ResponseId
# 1                                                         NaN         NaN
# 2                                                         NaN         NaN
# 3                                                         NaN         NaN
# 4                                                         NaN         NaN
# 5                                                         NaN         NaN
# ...                                                       ...         ...
# 73264       DevOps function;Microservices;Developer portal...         Yes
# 73265                                           None of these          No
# 73266                                           None of these          No
# 73267                                                     NaN         NaN
# 73268                                                     NaN         NaN
#
#            TrueFalse_2  TrueFalse_3           SurveyLength  \
# ResponseId
# 1                  NaN          NaN                    NaN
# 2                  NaN          NaN               Too long
# 3                  NaN          NaN  Appropriate in length
# 4                  NaN          NaN  Appropriate in length
# 5                  NaN          NaN               Too long
# ...                ...          ...                    ...
# 73264              Yes          Yes               Too long
# 73265              Yes          Yes               Too long
# 73266               No           No  Appropriate in length
# 73267              NaN          NaN  Appropriate in length
# 73268              NaN          NaN  Appropriate in length
#
#                             SurveyEase ConvertedCompYearly
# ResponseId
# 1                                  NaN                 NaN
# 2                            Difficult                 NaN
# 3           Neither easy nor difficult             40205.0
# 4                                 Easy            215232.0
# 5                                 Easy                 NaN
# ...                                ...                 ...
# 73264                             Easy                 NaN
# 73265                             Easy                 NaN
# 73266                             Easy                 NaN
# 73267                             Easy                 NaN
# 73268                             Easy                 NaN
#
# [73268 rows x 78 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# Get years of coding for respondand 1 to 50 
df.loc[1:50, 'YearsCode']
# Out:
# ResponseId
# 1     NaN
# 2     NaN
# 3      14
# 4      20
# 5       8
# 6      15
# 7       3
# 8       1
# 9       6
# 10     37
# 11      5
# 12     12
# 13     12
# 14     22
# 15     11
# 16      4
# 17      7
# 18     13
# 19     36
# 20      2
# 21      1
# 22      5
# 23     25
# 24     10
# 25     40
# 26     16
# 27     10
# 28      4
# 29     20
# 30     27
# 31    NaN
# 32     24
# 33      3
# 34      8
# 35      6
# 36     16
# 37     12
# 38     19
# 39      2
# 40     24
# 41     20
# 42      3
# 43      4
# 44     15
# 45      6
# 46      4
# 47      7
# 48      6
# 49     40
# 50      7
# Name: YearsCode, dtype: object

# %%
df_schema
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# S1             QID1  <span style="font-size:22px; font-family: aria...
# MainBranch     QID2  Which of the following options best describes ...
# Employment   QID296  Which of the following best describes your cur...
# ...             ...                                                ...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
# TrueFalse_1  QID294  Are you involved in supporting new hires durin...
# TrueFalse_2  QID294  Do you use learning resources provided by your...
# TrueFalse_3  QID294  Does your employer give you time to learn new ...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# S1               False    DB       TB
# MainBranch        True    MC     SAVR
# Employment       False    MC     MAVR
# ...                ...   ...      ...
# Frequency_2        NaN    MC     MAVR
# Frequency_3        NaN    MC     MAVR
# TrueFalse_1        NaN    MC     MAVR
# TrueFalse_2        NaN    MC     MAVR
# TrueFalse_3        NaN    MC     MAVR
#
# [79 rows x 5 columns]

# %%
df_schema['question']
# Out:
# qname
# S0             <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                       Browser Meta Info
# S1             <span style="font-size:22px; font-family: aria...
# MainBranch     Which of the following options best describes ...
# Employment     Which of the following best describes your cur...
#                                      ...
# Frequency_2    Interacting with people outside of your immedi...
# Frequency_3    Encountering knowledge silos (where one indivi...
# TrueFalse_1    Are you involved in supporting new hires durin...
# TrueFalse_2    Do you use learning resources provided by your...
# TrueFalse_3    Does your employer give you time to learn new ...
# Name: question, Length: 79, dtype: object

# %%
df_schema.loc['CodingActivities','question']
# Out:
# 'Which of the following best describes the code you write outside of work? Select all that apply.'

# %%
# Filtering data
#filter if the employment is full time
filt= (df['Employment'] == 'Employed, full-time')
# filter based on list of countries
countries = ['Canada', 'France', 'United States of America']
filt2= df['Country'].isin(countries)
#filter based on string
filt3= df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

df.loc[filt3, ['Employment','ConvertedCompYearly','Country','LanguageHaveWorkedWith','YearsCodePro','EdLevel']]
# Out:
#                                                    Employment  \
# ResponseId
# 3                                         Employed, full-time
# 7                                          Student, part-time
# 12          Employed, full-time;Independent contractor, fr...
# 15          Employed, full-time;Independent contractor, fr...
# 17                                        Employed, full-time
# ...                                                       ...
# 73258                                      Student, full-time
# 73262                                     Employed, full-time
# 73264                                     Employed, full-time
# 73265                                     Employed, full-time
# 73266                                     Employed, full-time
#
#             ConvertedCompYearly  \
# ResponseId
# 3                       40205.0
# 7                           NaN
# 12                     194400.0
# 15                     110000.0
# 17                      19224.0
# ...                         ...
# 73258                       NaN
# 73262                       NaN
# 73264                       NaN
# 73265                       NaN
# 73266                       NaN
#
#                                                       Country  \
# ResponseId
# 3           United Kingdom of Great Britain and Northern I...
# 7                                                       India
# 12                                   United States of America
# 15                                   United States of America
# 17                                             Czech Republic
# ...                                                       ...
# 73258                                                   India
# 73262                                                  France
# 73264                                                 Nigeria
# 73265                                United States of America
# 73266                                United States of America
#
#                                        LanguageHaveWorkedWith YearsCodePro  \
# ResponseId
# 3                           C#;C++;HTML/CSS;JavaScript;Python            5
# 7               C++;HTML/CSS;JavaScript;PHP;Python;TypeScript          NaN
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL           10
# 15                HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala            5
# 17                                       C#;Java;PHP;Python;R            4
# ...                                                       ...          ...
# 73258                                            C;Python;SQL          NaN
# 73262       Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...            2
# 73264       Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...            5
# 73265               Bash/Shell;HTML/CSS;JavaScript;Python;SQL            5
# 73266                      HTML/CSS;JavaScript;PHP;Python;SQL           33
#
#                                                       EdLevel
# ResponseId
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7           Secondary school (e.g. American high school, G...
# 12               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 17               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 73258       Secondary school (e.g. American high school, G...
# 73262         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73264            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73265         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73266            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# [34155 rows x 6 columns]

# %%
df.loc[~filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 10                             I am a developer by profession
# ...                                                       ...
# 73257                          I am a developer by profession
# 73258                                   I am learning to code
# 73261                          I am a developer by profession
# 73263                                   I am learning to code
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 6                                          Student, full-time
# 7                                          Student, part-time
# 8                          Not employed, but looking for work
# 10          Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 73257                  Student, part-time;Employed, part-time
# 73258                                      Student, full-time
# 73261                  Employed, full-time;Student, part-time
# 73263                  Student, full-time;Employed, part-time
# 73268       Independent contractor, freelancer, or self-em...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 10                                  Fully remote
# ...                                          ...
# 73257       Hybrid (some remote, some in-person)
# 73258                                        NaN
# 73261       Hybrid (some remote, some in-person)
# 73263       Hybrid (some remote, some in-person)
# 73268                               Fully remote
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 6                                                         NaN
# 7                                                         NaN
# 8                                                         NaN
# 10          Hobby;Contribute to open-source projects;Boots...
# ...                                                       ...
# 73257                                 School or academic work
# 73258                                                     NaN
# 73261                                 School or academic work
# 73263                                 School or academic work
# 73268       Hobby;Contribute to open-source projects;Boots...
#
#                                                       EdLevel  \
# ResponseId
# 1                                                         NaN
# 6             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7           Secondary school (e.g. American high school, G...
# 8           Some college/university study without earning ...
# 10          Some college/university study without earning ...
# ...                                                       ...
# 73257            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73258       Secondary school (e.g. American high school, G...
# 73261            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73263       Secondary school (e.g. American high school, G...
# 73268            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                                         NaN
# 6           Books / Physical media;School (i.e., Universit...
# 7           Other online resources (e.g., videos, blogs, f...
# 8                             Online Courses or Certification
# 10          Books / Physical media;Other online resources ...
# ...                                                       ...
# 73257       Books / Physical media;Other online resources ...
# 73258       Books / Physical media;Other online resources ...
# 73261                 School (i.e., University, College, etc)
# 73263       Other online resources (e.g., videos, blogs, f...
# 73268       Books / Physical media;Friend or family member...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 6                                                         NaN
# 7                   Stack Overflow;Video-based Online Courses
# 8                                                         NaN
# 10          Technical documentation;Blogs;Written Tutorial...
# ...                                                       ...
# 73257       Technical documentation;Stack Overflow;Online ...
# 73258       Technical documentation;Blogs;Written Tutorial...
# 73261                                                     NaN
# 73263       Technical documentation;Written Tutorials;Stac...
# 73268       Technical documentation;Blogs;Programming Game...
#
#            LearnCodeCoursesCert YearsCode YearsCodePro  ...  \
# ResponseId                                              ...
# 1                           NaN       NaN          NaN  ...
# 6                           NaN        15          NaN  ...
# 7                           NaN         3          NaN  ...
# 8                Coursera;Udemy         1          NaN  ...
# 10                          NaN        37           30  ...
# ...                         ...       ...          ...  ...
# 73257            Coursera;Udemy         9          NaN  ...
# 73258                       NaN         7          NaN  ...
# 73261                       NaN         8          NaN  ...
# 73263                       NaN         4          NaN  ...
# 73268         Udemy;Pluralsight        16            5  ...
#
#                   TimeSearching        TimeAnswering Onboarding  \
# ResponseId
# 1                           NaN                  NaN        NaN
# 6                           NaN                  NaN        NaN
# 7                           NaN                  NaN        NaN
# 8                           NaN                  NaN        NaN
# 10                          NaN                  NaN        NaN
# ...                         ...                  ...        ...
# 73257                       NaN                  NaN        NaN
# 73258                       NaN                  NaN        NaN
# 73261       15-30 minutes a day  30-60 minutes a day  Very long
# 73263                       NaN                  NaN        NaN
# 73268                       NaN                  NaN        NaN
#
#                                              ProfessionalTech TrueFalse_1  \
# ResponseId
# 1                                                         NaN         NaN
# 6                                                         NaN         NaN
# 7                                                         NaN         NaN
# 8                                                         NaN         NaN
# 10                                                        NaN         NaN
# ...                                                       ...         ...
# 73257                                                     NaN         NaN
# 73258                                                     NaN         NaN
# 73261       DevOps function;Developer portal or other cent...          No
# 73263                                                     NaN         NaN
# 73268                                                     NaN         NaN
#
#            TrueFalse_2  TrueFalse_3           SurveyLength  \
# ResponseId
# 1                  NaN          NaN                    NaN
# 6                  NaN          NaN  Appropriate in length
# 7                  NaN          NaN  Appropriate in length
# 8                  NaN          NaN  Appropriate in length
# 10                 NaN          NaN  Appropriate in length
# ...                ...          ...                    ...
# 73257              NaN          NaN  Appropriate in length
# 73258              NaN          NaN              Too short
# 73261               No          Yes  Appropriate in length
# 73263              NaN          NaN  Appropriate in length
# 73268              NaN          NaN  Appropriate in length
#
#                             SurveyEase ConvertedCompYearly
# ResponseId
# 1                                  NaN                 NaN
# 6                                 Easy                 NaN
# 7                                 Easy                 NaN
# 8                                 Easy                 NaN
# 10                                Easy                 NaN
# ...                                ...                 ...
# 73257                             Easy                 NaN
# 73258                             Easy                 NaN
# 73261                             Easy                 NaN
# 73263       Neither easy nor difficult                 NaN
# 73268                             Easy                 NaN
#
# [30306 rows x 78 columns]

# %%
#rename a column
df.rename(columns={'ConvertedCompYearly':'Annual_Salary_USD'}, inplace=True)
df['Annual_Salary_USD']
#update values in column using map function
#df['Hobbyist'].map({'Yes:True, 'No': False})
# Out:
# ResponseId
# 1             NaN
# 2             NaN
# 3         40205.0
# 4        215232.0
# 5             NaN
#            ...
# 73264         NaN
# 73265         NaN
# 73266         NaN
# 73267         NaN
# 73268         NaN
# Name: Annual_Salary_USD, Length: 73268, dtype: float64

# %%
df.sort_values(by=['Country', 'Annual_Salary_USD'],ascending=[True, False],inplace=True)
df[['Country', 'Annual_Salary_USD']].head(100)
# Out:
#                 Country  Annual_Salary_USD
# ResponseId
# 38513       Afghanistan           158484.0
# 43640       Afghanistan            92448.0
# 6892        Afghanistan            15600.0
# 43691       Afghanistan            13212.0
# 2449        Afghanistan            10894.0
# ...                 ...                ...
# 68078           Albania               36.0
# 21121           Albania                NaN
# 40659           Albania                NaN
# 66018           Albania                NaN
# 43538           Albania                NaN
#
# [100 rows x 2 columns]

# %%
df.describe()
# Out:
#           CompTotal  VCHostingPersonal use  VCHostingProfessional use  \
# count  3.842200e+04                    0.0                        0.0
# mean   2.342434e+52                    NaN                        NaN
# std    4.591478e+54                    NaN                        NaN
# min    0.000000e+00                    NaN                        NaN
# 25%    3.000000e+04                    NaN                        NaN
# 50%    7.750000e+04                    NaN                        NaN
# 75%    1.540000e+05                    NaN                        NaN
# max    9.000000e+56                    NaN                        NaN
#
#             WorkExp  Annual_Salary_USD
# count  36769.000000       3.807100e+04
# mean      10.242378       1.707613e+05
# std        8.706850       7.814132e+05
# min        0.000000       1.000000e+00
# 25%        4.000000       3.583200e+04
# 50%        8.000000       6.784500e+04
# 75%       15.000000       1.200000e+05
# max       50.000000       5.000000e+07

# %%
df['Ethnicity'].value_counts(normalize=True)
# Out:
# European                                                                      0.210323
# White                                                                         0.196232
# White;European                                                                0.125140
# Indian                                                                        0.075424
# Asian                                                                         0.048162
#                                                                                 ...
# White;European;Middle Eastern;North African;Multiracial                       0.000014
# Or, in your own words:;Middle Eastern;Multiracial                             0.000014
# European;Middle Eastern;Ethnoreligious group;Multiracial                      0.000014
# Indian;Middle Eastern;Multiracial                                             0.000014
# Indian;European;Asian;East Asian;Southeast Asian;South Asian;Central Asian    0.000014
# Name: Ethnicity, Length: 1055, dtype: float64

# %%
country_grp = df.groupby(['Country'])
country_grp.get_group('Somalia')
#country_grp['Employment'].value_counts()
# Out:
#                                                    MainBranch  \
# ResponseId
# 28470                          I am a developer by profession
# 61514                          I am a developer by profession
# 62507                          I am a developer by profession
# 56102                          I am a developer by profession
# 21145                                   I am learning to code
# 31940                          I am a developer by profession
# 66282       I am not primarily a developer, but I write co...
# 60024                          I am a developer by profession
# 70148                          I am a developer by profession
# 42523                          I am a developer by profession
# 68674                          I am a developer by profession
# 69012                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 28470                                     Employed, full-time
# 61514                                      Student, full-time
# 62507                                     Employed, full-time
# 56102                                     Employed, full-time
# 21145                                     Employed, part-time
# 31940                                      Student, full-time
# 66282                                     Employed, full-time
# 60024                                     Employed, full-time
# 70148       Independent contractor, freelancer, or self-em...
# 42523                                     Employed, full-time
# 68674       Independent contractor, freelancer, or self-em...
# 69012                                     Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 28470       Hybrid (some remote, some in-person)
# 61514                                        NaN
# 62507                             Full in-person
# 56102                             Full in-person
# 21145                             Full in-person
# 31940                                        NaN
# 66282                             Full in-person
# 60024                             Full in-person
# 70148                             Full in-person
# 42523       Hybrid (some remote, some in-person)
# 68674                               Fully remote
# 69012                             Full in-person
#
#                                              CodingActivities  \
# ResponseId
# 28470       Contribute to open-source projects;Freelance/c...
# 61514                                                     NaN
# 62507                                                   Hobby
# 56102                            I don’t code outside of work
# 21145       Hobby;Contribute to open-source projects;Boots...
# 31940                                                     NaN
# 66282                                                   Hobby
# 60024                                                   Hobby
# 70148                                 Freelance/contract work
# 42523       Hobby;Contribute to open-source projects;Freel...
# 68674       Hobby;Bootstrapping a business;Freelance/contr...
# 69012                                                   Hobby
#
#                                                       EdLevel  \
# ResponseId
# 28470            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61514       Secondary school (e.g. American high school, G...
# 62507            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 56102            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 21145       Some college/university study without earning ...
# 31940            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66282            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 60024            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 70148            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 42523            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 68674            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 69012         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                     LearnCode  \
# ResponseId
# 28470       School (i.e., University, College, etc);On the...
# 61514                         Online Courses or Certification
# 62507       Other online resources (e.g., videos, blogs, f...
# 56102       Friend or family member;School (i.e., Universi...
# 21145                 School (i.e., University, College, etc)
# 31940          Books / Physical media;Friend or family member
# 66282                 School (i.e., University, College, etc)
# 60024       Friend or family member;School (i.e., Universi...
# 70148       Other online resources (e.g., videos, blogs, f...
# 42523       Other online resources (e.g., videos, blogs, f...
# 68674         Online Courses or Certification;Coding Bootcamp
# 69012                         Online Courses or Certification
#
#                                               LearnCodeOnline  \
# ResponseId
# 28470                                                     NaN
# 61514                                                     NaN
# 62507       Technical documentation;Blogs;Stack Overflow;V...
# 56102                                                     NaN
# 21145                                                     NaN
# 31940                                                     NaN
# 66282                                                     NaN
# 60024                                                     NaN
# 70148       Technical documentation;Video-based Online Cou...
# 42523       Technical documentation;Written Tutorials;Vide...
# 68674                                                     NaN
# 69012                                                     NaN
#
#                                    LearnCodeCoursesCert YearsCode  \
# ResponseId
# 28470       Coursera;Codecademy;Pluralsight;edX;Udacity         7
# 61514                                             Other        10
# 62507                                             Udemy         8
# 56102                                               NaN         9
# 21145                                               NaN         4
# 31940                                               NaN         3
# 66282                                               NaN         4
# 60024                                               NaN         3
# 70148                                             Udemy         4
# 42523                                       Pluralsight         5
# 68674                                             Udemy         6
# 69012                                             Udemy        15
#
#                 YearsCodePro  \
# ResponseId
# 28470                      5
# 61514                    NaN
# 62507                      5
# 56102                      6
# 21145                    NaN
# 31940                    NaN
# 66282       Less than 1 year
# 60024       Less than 1 year
# 70148                      2
# 42523                      1
# 68674                      3
# 69012                      8
#
#                                                       DevType  \
# ResponseId
# 28470                                       Developer, mobile
# 61514                                                     NaN
# 62507       Developer, full-stack;Developer, back-end;Deve...
# 56102            Developer, full-stack;Database administrator
# 21145                         Marketing or sales professional
# 31940                                                     NaN
# 66282                         Marketing or sales professional
# 60024       Developer, front-end;Developer, full-stack;Dev...
# 70148       Developer, front-end;Developer, full-stack;Dev...
# 42523                       Developer, mobile;Product manager
# 68674                                   Developer, full-stack
# 69012                                   Developer, full-stack
#
#                                                       OrgSize  \
# ResponseId
# 28470                                      10 to 19 employees
# 61514                                                     NaN
# 62507                                            I don’t know
# 56102                                        2 to 9 employees
# 21145                                                     NaN
# 31940                                                     NaN
# 66282       Just me - I am a freelancer, sole proprietor, ...
# 60024                                    500 to 999 employees
# 70148                                      20 to 99 employees
# 42523                                            I don’t know
# 68674       Just me - I am a freelancer, sole proprietor, ...
# 69012                                      10 to 19 employees
#
#                            PurchaseInfluence  \
# ResponseId
# 28470       I have a great deal of influence
# 61514                                    NaN
# 62507          I have little or no influence
# 56102                  I have some influence
# 21145                                    NaN
# 31940                                    NaN
# 66282          I have little or no influence
# 60024          I have little or no influence
# 70148                  I have some influence
# 42523       I have a great deal of influence
# 68674       I have a great deal of influence
# 69012                  I have some influence
#
#                                                    BuyNewTool  Country  \
# ResponseId
# 28470       Start a free trial;Visit developer communities...  Somalia
# 61514                                                     NaN  Somalia
# 62507                                      Start a free trial  Somalia
# 56102       Start a free trial;Visit developer communities...  Somalia
# 21145         Visit developer communities like Stack Overflow  Somalia
# 31940                         Ask developers I know/work with  Somalia
# 66282       Start a free trial;Ask developers I know/work ...  Somalia
# 60024       Ask developers I know/work with;Research compa...  Somalia
# 70148         Visit developer communities like Stack Overflow  Somalia
# 42523                                      Start a free trial  Somalia
# 68674       Visit developer communities like Stack Overflo...  Somalia
# 69012         Visit developer communities like Stack Overflow  Somalia
#
#                              Currency  CompTotal CompFreq  \
# ResponseId
# 28470       USD\tUnited States dollar    12000.0   Yearly
# 61514                             NaN        NaN      NaN
# 62507       USD\tUnited States dollar        NaN  Monthly
# 56102            SOS\tSomali shilling        NaN  Monthly
# 21145                             NaN        NaN      NaN
# 31940                             NaN        NaN      NaN
# 66282       USD\tUnited States dollar        NaN  Monthly
# 60024       USD\tUnited States dollar        NaN      NaN
# 70148            SOS\tSomali shilling        NaN  Monthly
# 42523       USD\tUnited States dollar        NaN  Monthly
# 68674       USD\tUnited States dollar        NaN   Weekly
# 69012       USD\tUnited States dollar        NaN  Monthly
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 28470       C;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL;...
# 61514                             HTML/CSS;JavaScript;PHP;SQL
# 62507                      HTML/CSS;JavaScript;SQL;TypeScript
# 56102                                                  C#;SQL
# 21145                                   APL;C++;HTML/CSS;Java
# 31940                     Dart;HTML/CSS;Kotlin;PHP;Python;SQL
# 66282                                                     NaN
# 60024                                                     C++
# 70148                          HTML/CSS;JavaScript;TypeScript
# 42523                           C++;JavaScript;Kotlin;PHP;SQL
# 68674                                        HTML/CSS;PHP;SQL
# 69012                                              JavaScript
#
#                               LanguageWantToWorkWith  \
# ResponseId
# 28470       Kotlin;Objective-C;R;Solidity;TypeScript
# 61514                    HTML/CSS;JavaScript;PHP;SQL
# 62507             HTML/CSS;JavaScript;SQL;TypeScript
# 56102                                            PHP
# 21145                                            APL
# 31940                                            NaN
# 66282                                            NaN
# 60024                                     JavaScript
# 70148                              Python;TypeScript
# 42523                                     Dart;Swift
# 68674                                        Go;Java
# 69012                                     TypeScript
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 28470       Cloud Firestore;Microsoft SQL Server;MongoDB;M...
# 61514                                                   MySQL
# 62507                                          MongoDB;Oracle
# 56102                                    Microsoft SQL Server
# 21145       Cassandra;Microsoft SQL Server;Firebase Realti...
# 31940                        MySQL;Firebase Realtime Database
# 66282                                                   MySQL
# 60024                                                     NaN
# 70148                                      MongoDB;PostgreSQL
# 42523       Microsoft SQL Server;MongoDB;MySQL;Oracle;Fire...
# 68674                                                   MySQL
# 69012                                                   MySQL
#
#            DatabaseWantToWorkWith  \
# ResponseId
# 28470                         NaN
# 61514                       MySQL
# 62507              MongoDB;Oracle
# 56102        Microsoft SQL Server
# 21145                         NaN
# 31940                         NaN
# 66282                       MySQL
# 60024                         NaN
# 70148                  PostgreSQL
# 42523          MongoDB;PostgreSQL
# 68674                         NaN
# 69012                  PostgreSQL
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 28470                                         Firebase;Heroku
# 61514                                        AWS;Google Cloud
# 62507                                                     NaN
# 56102                                                     NaN
# 21145       AWS;Google Cloud;Managed Hosting;Microsoft Azu...
# 31940                                Firebase;Managed Hosting
# 66282                                                     NaN
# 60024                                                     NaN
# 70148                                  Heroku;Managed Hosting
# 42523                            Firebase;Google Cloud;Heroku
# 68674                        AWS;DigitalOcean;Firebase;Linode
# 69012                                            DigitalOcean
#
#                       PlatformWantToWorkWith  \
# ResponseId
# 28470                       AWS;Google Cloud
# 61514                       AWS;Google Cloud
# 62507                                    NaN
# 56102                                    NaN
# 21145                                    NaN
# 31940                                    NaN
# 66282                                    NaN
# 60024                                    NaN
# 70148                       AWS;DigitalOcean
# 42523                                    NaN
# 68674       AWS;DigitalOcean;Firebase;Linode
# 69012                                    AWS
#
#                               WebframeHaveWorkedWith  \
# ResponseId
# 28470                jQuery;Next.js;Node.js;React.js
# 61514                        jQuery;Laravel;React.js
# 62507                 Angular;Express;jQuery;Node.js
# 56102                          ASP.NET;ASP.NET Core
# 21145                                        Angular
# 31940                                        Laravel
# 66282                                            NaN
# 60024                               Node.js;React.js
# 70148       Angular;Express;Next.js;Node.js;React.js
# 42523                       Express;Node.js;React.js
# 68674                                         jQuery
# 69012                                        Node.js
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 28470                               Angular;Angular.js;Vue.js
# 61514                                 jQuery;Laravel;React.js
# 62507                          Angular;Express;jQuery;Node.js
# 56102                                   ASP.NET;ASP.NET Core
# 21145                                                     NaN
# 31940                                                     NaN
# 66282                                                     NaN
# 60024                                        Node.js;React.js
# 70148                 Django;Express;Next.js;Node.js;React.js
# 42523                                Express;Node.js;React.js
# 68674       Angular;Angular.js;Django;jQuery;Next.js;Node....
# 69012                                                 Next.js
#
#            MiscTechHaveWorkedWith   MiscTechWantToWorkWith  \
# ResponseId
# 28470        React Native;Xamarin  React Native;TensorFlow
# 61514                         NaN                      NaN
# 62507                         NaN                      NaN
# 56102                        .NET                      NaN
# 21145                        .NET                      NaN
# 31940                         NaN                      NaN
# 66282                         NaN                      NaN
# 60024                         NaN                      NaN
# 70148                React Native             React Native
# 42523                     Flutter                  Flutter
# 68674                         NaN                      NaN
# 69012                         NaN                      NaN
#
#                         ToolsTechHaveWorkedWith  \
# ResponseId
# 28470                                       NaN
# 61514                                       npm
# 62507                               Ansible;npm
# 56102                                       NaN
# 21145                              Ansible;Flow
# 31940                                       NaN
# 66282                                       NaN
# 60024                                       npm
# 70148       Docker;Homebrew;Kubernetes;npm;Yarn
# 42523                                       npm
# 68674                         Docker;npm;Puppet
# 69012                                       npm
#
#                         ToolsTechWantToWorkWith  \
# ResponseId
# 28470                                       NaN
# 61514                                       npm
# 62507                               Ansible;npm
# 56102                                       NaN
# 21145                                       NaN
# 31940                                       NaN
# 66282                                       NaN
# 60024                                       npm
# 70148       Docker;Homebrew;Kubernetes;npm;Yarn
# 42523                                Docker;npm
# 68674                         Docker;npm;Puppet
# 69012                                      Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 28470       Android Studio;Atom;Eclipse;IPython/Jupyter;No...
# 61514                         Sublime Text;Visual Studio Code
# 62507                             Visual Studio Code;Webstorm
# 56102                        Visual Studio;Visual Studio Code
# 21145       Android Studio;RAD Studio (Delphi, C++ Builder...
# 31940       Android Studio;Atom;Eclipse;PhpStorm;PyCharm;V...
# 66282       Android Studio;Notepad++;Sublime Text;Visual S...
# 60024                                           Visual Studio
# 70148                                      Visual Studio Code
# 42523        Android Studio;IntelliJ;Visual Studio Code;Xcode
# 68674       Android Studio;PhpStorm;Sublime Text;Visual St...
# 69012                                      Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith  \
# ResponseId
# 28470        IPython/Jupyter;PyCharm;Visual Studio Code;Xcode
# 61514                         Sublime Text;Visual Studio Code
# 62507                             Visual Studio Code;Webstorm
# 56102                                           Visual Studio
# 21145                                          Android Studio
# 31940                                                     NaN
# 66282       Android Studio;Notepad++;Sublime Text;Visual S...
# 60024                                           Visual Studio
# 70148                                      Visual Studio Code
# 42523        Android Studio;IntelliJ;Visual Studio Code;Xcode
# 68674       Android Studio;PhpStorm;Sublime Text;Visual St...
# 69012                                      Visual Studio Code
#
#                                         OpSysProfessional use  \
# ResponseId
# 28470                                                   macOS
# 61514                                                 Windows
# 62507       Linux-based;Windows;Windows Subsystem for Linu...
# 56102                                     Linux-based;Windows
# 21145           BSD;Windows;Windows Subsystem for Linux (WSL)
# 31940                                                 Windows
# 66282                                                     NaN
# 60024               Windows;Windows Subsystem for Linux (WSL)
# 70148                                       Linux-based;macOS
# 42523                                       Linux-based;macOS
# 68674                                                     NaN
# 69012                       Windows Subsystem for Linux (WSL)
#
#                                             OpSysPersonal use  \
# ResponseId
# 28470                                           macOS;Windows
# 61514                                                 Windows
# 62507       Linux-based;Windows;Windows Subsystem for Linu...
# 56102                                     Linux-based;Windows
# 21145       BSD;Linux-based;Windows;Windows Subsystem for ...
# 31940                                                 Windows
# 66282                                                 Windows
# 60024               Windows;Windows Subsystem for Linux (WSL)
# 70148                                       Linux-based;macOS
# 42523                                       Linux-based;macOS
# 68674                                                 Windows
# 69012                                                 Windows
#
#            VersionControlSystem  \
# ResponseId
# 28470                       Git
# 61514                       Git
# 62507                       SVN
# 56102           I don't use one
# 21145         Git;Mercurial;SVN
# 31940                       Git
# 66282           I don't use one
# 60024                       Git
# 70148                       Git
# 42523                       Git
# 68674                   Git;SVN
# 69012                       Git
#
#                                                 VCInteraction  \
# ResponseId
# 28470                                Code editor;Command-line
# 61514                                             Code editor
# 62507       Command-line;Dedicated version control GUI app...
# 56102                                                     NaN
# 21145       Code editor;Command-line;Version control hosti...
# 31940                                Code editor;Command-line
# 66282                                                     NaN
# 60024                                            Command-line
# 70148                                Code editor;Command-line
# 42523                                            Command-line
# 68674       Command-line;Version control hosting service w...
# 69012                                            Command-line
#
#             VCHostingPersonal use  VCHostingProfessional use  \
# ResponseId
# 28470                         NaN                        NaN
# 61514                         NaN                        NaN
# 62507                         NaN                        NaN
# 56102                         NaN                        NaN
# 21145                         NaN                        NaN
# 31940                         NaN                        NaN
# 66282                         NaN                        NaN
# 60024                         NaN                        NaN
# 70148                         NaN                        NaN
# 42523                         NaN                        NaN
# 68674                         NaN                        NaN
# 69012                         NaN                        NaN
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 28470                                                     NaN
# 61514                                       Microsoft Planner
# 62507                         Confluence;Jira Work Management
# 56102                                                     NaN
# 21145       Adobe Workfront;Confluence;Jira Work Managemen...
# 31940                                                     NaN
# 66282                                                     NaN
# 60024                                                     NaN
# 70148                                                  Notion
# 42523                                                  Notion
# 68674                                                     NaN
# 69012                                       Microsoft Planner
#
#                              OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 28470                                                   NaN
# 61514                                     Microsoft Planner
# 62507                       Confluence;Jira Work Management
# 56102                                                   NaN
# 21145       Adobe Workfront;Stack Overflow for Teams;Trello
# 31940                                                   NaN
# 66282                                                   NaN
# 60024                                                   NaN
# 70148                                                Notion
# 42523                                                Notion
# 68674                                                   NaN
# 69012                              Stack Overflow for Teams
#
#              OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# ResponseId
# 28470                           Slack;Zoom                    Slack;Zoom
# 61514                                 Zoom                          Zoom
# 62507                                  NaN                           NaN
# 56102                                  NaN                           NaN
# 21145       Coolfire Core;Google Chat;Zoom                           NaN
# 31940                                  NaN                           NaN
# 66282                                  NaN                           NaN
# 60024                                 Zoom                          Zoom
# 70148                           Slack;Zoom                         Slack
# 42523                     Google Chat;Zoom              Google Chat;Zoom
# 68674                             Symphony                      Symphony
# 69012                                 Zoom                   Google Chat
#
#                 Blockchain                                         NEWSOSites  \
# ResponseId
# 28470       Very favorable                      Stack Overflow;Stack Exchange
# 61514                  NaN  I have never visited Stack Overflow or the Sta...
# 62507               Unsure                      Stack Overflow;Stack Exchange
# 56102          Unfavorable                      Stack Overflow;Stack Exchange
# 21145       Very favorable  Collectives on Stack Overflow;Stack Overflow f...
# 31940       Very favorable       Collectives on Stack Overflow;Stack Exchange
# 66282               Unsure                      Collectives on Stack Overflow
# 60024          Indifferent                                                NaN
# 70148            Favorable                                     Stack Overflow
# 42523       Very favorable  Collectives on Stack Overflow;Stack Overflow f...
# 68674          Indifferent                      Stack Overflow;Stack Exchange
# 69012               Unsure                                     Stack Overflow
#
#                                 SOVisitFreq                SOAccount  \
# ResponseId
# 28470                Multiple times per day                      Yes
# 61514                                   NaN                       No
# 62507                Multiple times per day                      Yes
# 56102                  A few times per week                      Yes
# 21145       A few times per month or weekly                      Yes
# 31940                 Daily or almost daily                      Yes
# 66282       A few times per month or weekly  Not sure/can't remember
# 60024                  A few times per week                      Yes
# 70148                 Daily or almost daily                      Yes
# 42523                  A few times per week                      Yes
# 68674                  A few times per week                      Yes
# 69012                Multiple times per day  Not sure/can't remember
#
#                                                    SOPartFreq  \
# ResponseId
# 28470                                    A few times per week
# 61514                                                     NaN
# 62507                     Less than once per month or monthly
# 56102                     Less than once per month or monthly
# 21145                         A few times per month or weekly
# 31940       I have never participated in Q&A on Stack Over...
# 66282                                                     NaN
# 60024       I have never participated in Q&A on Stack Over...
# 70148                     Less than once per month or monthly
# 42523                                   Daily or almost daily
# 68674                     Less than once per month or monthly
# 69012                                                     NaN
#
#                      SOComm              Age  \
# ResponseId
# 28470       Yes, definitely  18-24 years old
# 61514         Yes, somewhat  18-24 years old
# 62507       Yes, definitely  25-34 years old
# 56102         Yes, somewhat  25-34 years old
# 21145       Yes, definitely  35-44 years old
# 31940         Yes, somewhat  18-24 years old
# 66282               Neutral  18-24 years old
# 60024               Neutral  18-24 years old
# 70148       Yes, definitely  18-24 years old
# 42523       Yes, definitely  18-24 years old
# 68674         Yes, somewhat  18-24 years old
# 69012               Neutral  25-34 years old
#
#                                                        Gender Trans  \
# ResponseId
# 28470                                                     Man    No
# 61514                                                     Man   Yes
# 62507                                                     Man    No
# 56102                                                     Man    No
# 21145       Man;Woman;Non-binary, genderqueer, or gender n...   Yes
# 31940                                                     Man    No
# 66282                                                     Man   NaN
# 60024                                                     Man    No
# 70148                                                     Man    No
# 42523                                                     Man    No
# 68674                                                     Man    No
# 69012                                                     Man    No
#
#                           Sexuality               Ethnicity  \
# ResponseId
# 28470       Straight / Heterosexual           African;Black
# 61514                           NaN  European;African;Asian
# 62507       Straight / Heterosexual                 African
# 56102       Straight / Heterosexual                 African
# 21145             Prefer not to say       Prefer not to say
# 31940       Straight / Heterosexual                 African
# 66282                           NaN                 African
# 60024       Straight / Heterosexual                 African
# 70148                           NaN                 African
# 42523       Straight / Heterosexual                 African
# 68674       Straight / Heterosexual                 African
# 69012       Straight / Heterosexual                 African
#
#                 Accessibility       MentalHealth TBranch  \
# ResponseId
# 28470       None of the above  None of the above     Yes
# 61514                     NaN                NaN     NaN
# 62507       None of the above  None of the above     Yes
# 56102       None of the above  None of the above     Yes
# 21145       Prefer not to say  Prefer not to say     NaN
# 31940       None of the above  None of the above     NaN
# 66282                     NaN                NaN     Yes
# 60024       None of the above  None of the above      No
# 70148       None of the above  None of the above     Yes
# 42523       None of the above  None of the above     Yes
# 68674       None of the above  None of the above     NaN
# 69012       None of the above  None of the above     Yes
#
#                              ICorPM  WorkExp                 Knowledge_1  \
# ResponseId
# 28470       Independent contributor      5.0                       Agree
# 61514                           NaN      NaN                         NaN
# 62507                People manager      8.0                       Agree
# 56102       Independent contributor      7.0  Neither agree nor disagree
# 21145                           NaN      NaN                         NaN
# 31940                           NaN      NaN                         NaN
# 66282       Independent contributor      5.0                         NaN
# 60024                           NaN      NaN                         NaN
# 70148       Independent contributor      2.0                       Agree
# 42523       Independent contributor      1.0  Neither agree nor disagree
# 68674                           NaN      NaN                         NaN
# 69012                People manager     35.0                       Agree
#
#                            Knowledge_2                 Knowledge_3  \
# ResponseId
# 28470       Neither agree nor disagree  Neither agree nor disagree
# 61514                              NaN                         NaN
# 62507                              NaN              Strongly agree
# 56102                         Disagree  Neither agree nor disagree
# 21145                              NaN                         NaN
# 31940                              NaN                         NaN
# 66282                              NaN                         NaN
# 60024                              NaN                         NaN
# 70148                              NaN                         NaN
# 42523                            Agree                       Agree
# 68674                              NaN                         NaN
# 69012       Neither agree nor disagree                       Agree
#
#                            Knowledge_4     Knowledge_5  \
# ResponseId
# 28470                            Agree  Strongly agree
# 61514                              NaN             NaN
# 62507                            Agree           Agree
# 56102                   Strongly agree           Agree
# 21145                              NaN             NaN
# 31940                              NaN             NaN
# 66282                              NaN             NaN
# 60024                              NaN             NaN
# 70148                         Disagree           Agree
# 42523                            Agree             NaN
# 68674                              NaN             NaN
# 69012       Neither agree nor disagree           Agree
#
#                            Knowledge_6 Knowledge_7        Frequency_1  \
# ResponseId
# 28470                            Agree       Agree   1-2 times a week
# 61514                              NaN         NaN                NaN
# 62507                              NaN       Agree  6-10 times a week
# 56102       Neither agree nor disagree       Agree              Never
# 21145                              NaN         NaN                NaN
# 31940                              NaN         NaN                NaN
# 66282                              NaN         NaN                NaN
# 60024                              NaN         NaN                NaN
# 70148                            Agree         NaN              Never
# 42523                            Agree       Agree   1-2 times a week
# 68674                              NaN         NaN                NaN
# 69012       Neither agree nor disagree       Agree   1-2 times a week
#
#                   Frequency_2       Frequency_3               TimeSearching  \
# ResponseId
# 28470        1-2 times a week  3-5 times a week         15-30 minutes a day
# 61514                     NaN               NaN                         NaN
# 62507       6-10 times a week  1-2 times a week      Over 120 minutes a day
# 56102        1-2 times a week               NaN        60-120 minutes a day
# 21145                     NaN               NaN                         NaN
# 31940                     NaN               NaN                         NaN
# 66282                     NaN               NaN  Less than 15 minutes a day
# 60024                     NaN               NaN                         NaN
# 70148                   Never               NaN         15-30 minutes a day
# 42523        1-2 times a week  1-2 times a week         15-30 minutes a day
# 68674                     NaN               NaN                         NaN
# 69012        1-2 times a week  3-5 times a week  Less than 15 minutes a day
#
#                          TimeAnswering      Onboarding  \
# ResponseId
# 28470              15-30 minutes a day      Just right
# 61514                              NaN             NaN
# 62507              15-30 minutes a day   Somewhat long
# 56102       Less than 15 minutes a day  Somewhat short
# 21145                              NaN             NaN
# 31940                              NaN             NaN
# 66282       Less than 15 minutes a day       Very long
# 60024                              NaN             NaN
# 70148              15-30 minutes a day      Just right
# 42523       Less than 15 minutes a day   Somewhat long
# 68674                              NaN             NaN
# 69012              15-30 minutes a day       Very long
#
#                                              ProfessionalTech TrueFalse_1  \
# ResponseId
# 28470                                           None of these         Yes
# 61514                                                     NaN         NaN
# 62507       DevOps function;Continuous integration (CI) an...         Yes
# 56102                                                     NaN         NaN
# 21145                                                     NaN         NaN
# 31940                                                     NaN         NaN
# 66282                                           None of these          No
# 60024                                                     NaN         NaN
# 70148                                                     NaN          No
# 42523       Developer portal or other central places to fi...         Yes
# 68674                                                     NaN         NaN
# 69012                                           None of these          No
#
#            TrueFalse_2 TrueFalse_3           SurveyLength  \
# ResponseId
# 28470               No         Yes  Appropriate in length
# 61514              NaN         NaN  Appropriate in length
# 62507               No         Yes               Too long
# 56102              NaN         NaN  Appropriate in length
# 21145              NaN         NaN               Too long
# 31940              NaN         NaN               Too long
# 66282               No          No               Too long
# 60024              NaN         NaN               Too long
# 70148              Yes         Yes               Too long
# 42523              Yes         Yes  Appropriate in length
# 68674              NaN         NaN               Too long
# 69012               No         Yes  Appropriate in length
#
#                             SurveyEase  Annual_Salary_USD
# ResponseId
# 28470       Neither easy nor difficult            12000.0
# 61514       Neither easy nor difficult                NaN
# 62507                             Easy                NaN
# 56102                             Easy                NaN
# 21145       Neither easy nor difficult                NaN
# 31940                             Easy                NaN
# 66282                        Difficult                NaN
# 60024                        Difficult                NaN
# 70148       Neither easy nor difficult                NaN
# 42523                             Easy                NaN
# 68674       Neither easy nor difficult                NaN
# 69012       Neither easy nor difficult                NaN

# %%
country_grp['Annual_Salary_USD'].agg(['median','mean'])
# Out:
#                                        median          mean
# Country
# Afghanistan                           10894.0  33914.666667
# Albania                               15360.0  24895.148148
# Algeria                                7440.0  12732.888889
# Andorra                               76784.0  98003.125000
# Angola                                 3073.5   6222.750000
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  17079.400000
# Viet Nam                              11388.0  37707.563830
# Yemen                                 15000.0  17464.666667
# Zambia                                 6612.0   8452.000000
# Zimbabwe                              11400.0  87596.000000
#
# [180 rows x 2 columns]

# %%
#df['YearsCode']= df['YearsCode'].astype(float)
df['YearsCode'].unique()
df['YearsCode'].replace('Less than 1 year', 0, inplace = True)
df['YearsCode'].replace('More than 50 years', 51, inplace = True)
df['YearsCode']= df['YearsCode'].astype(float)
df['YearsCode'].agg(['mean', 'median'])
# Out:
# mean      12.251307
# median     9.000000
# Name: YearsCode, dtype: float64
